# %%
#"Plot Notebook"
"Create a list of evenly-spaced numbers over the range and plot the sine of each x point"
# Out:
# 'Create a list of evenly-spaced numbers over the range and plot the sine of each x point'
